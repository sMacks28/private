# %% [markdown]
# ## Exercise 4
# ### Hydrogen Burning

# %%
# Import packages
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# For an easy access to the cross sections we import another package. With this package it is possible to read reaclib files and to get the cross sections at a specific temperature.

# %%
from class_files.reaclib_class import reaclib

# For this, we have to give the path of the Reaclib file
r = reaclib("hburning_reactions.dat")
r.read_reaclib()
# Out:
# Reading line 705

# %%
# With the class we can now access all reactions that are contained in the Reaclib
# For this we have to call the function "get_rate_at_temp", followed by the temperature in GK, 
# the reactants as a list, and the products as a list. The return value will be Avogadros number (NA)
# times the cross section at the given temperature.
# For example, we can access <ov>_pp * NA at 0.015 GK by:
NA_sigma_pp = r.get_rate_at_temp(0.015,["p","p"],["d"])

# %%
# Run winnet
! /home/teaching/WinNet/bin/winnet Hydrogen_burning.par >OUT 2>ERR

# %%
data = np.loadtxt("generated_energyT0.015GK..dat", skiprows=1)

time = data[:, 0]
totalenergy = data[:, 1]

plt.plot(time / (365*24*3600), totalenergy)
plt.xlabel('Time [s]')
plt.ylabel('Generated energy [erg/g/s]')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# DeprecationWarning                        Traceback (most recent call last)
# Cell In[15], line 6
#       3 time = data[:, 0]
#       4 totalenergy = data[:, 1]
# ----> 6 plt.plot(time / (365*24*3600), totalenergy)
#       7 plt.xlabel('Time [s]')
#       8 plt.ylabel('Generated energy [erg/g/s]')
#
# File /home/tools/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File /home/tools/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:2540, in gca()
#    2538 @_copy_docstring_and_deprecators(Figure.gca)
#    2539 def gca() -> Axes:
# -> 2540     return gcf().gca()
#
# File /home/tools/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:1000, in gcf()
#     998     return manager.canvas.figure
#     999 else:
# -> 1000     return figure()
#
# File /home/tools/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:934, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     924 if len(allnums) == max_open_warning >= 1:
#     925     _api.warn_external(
#     926         f"More than {max_open_warning} figures have been opened. "
#     927         f"Figures created through the pyplot interface "
#    (...)
#     931         f"Consider using `matplotlib.pyplot.close()`.",
#     932         RuntimeWarning)
# --> 934 manager = new_figure_manager(
#     935     num, figsize=figsize, dpi=dpi,
#     936     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#     937     FigureClass=FigureClass, **kwargs)
#     938 fig = manager.canvas.figure
#     939 if fig_label:
#
# File /home/tools/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:465, in new_figure_manager(*args, **kwargs)
#     463 """Create a new figure manager instance."""
#     464 _warn_if_gui_out_of_main_thread()
# --> 465 return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File /home/tools/anaconda3/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:27, in new_figure_manager(num, FigureClass, *args, **kwargs)
#      21 def new_figure_manager(num, *args, FigureClass=Figure, **kwargs):
#      22     """
#      23     Return a new figure manager for a new figure instance.
#      24
#      25     This function is part of the API expected by Matplotlib backends.
#      26     """
# ---> 27     return new_figure_manager_given_figure(num, FigureClass(*args, **kwargs))
#
# File /home/tools/anaconda3/lib/python3.10/site-packages/matplotlib/figure.py:2578, in Figure.__init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2575 self._set_artist_props(self.patch)
#    2576 self.patch.set_antialiased(False)
# -> 2578 FigureCanvasBase(self)  # Set self.canvas.
#    2580 if subplotpars is None:
#    2581     subplotpars = SubplotParams()
#
# File /home/tools/anaconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py:1721, in FigureCanvasBase.__init__(self, figure)
#    1719 def __init__(self, figure=None):
#    1720     from matplotlib.figure import Figure
# -> 1721     self._fix_ipython_backend2gui()
#    1722     self._is_idle_drawing = True
#    1723     self._is_saving = False
#
# File /home/tools/anaconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py:1758, in FigureCanvasBase._fix_ipython_backend2gui(cls)
#    1756     return
#    1757 from IPython.core import pylabtools as pt
# -> 1758 if (not hasattr(pt, "backend2gui")
#    1759         or not hasattr(ip, "enable_matplotlib")):
#    1760     # In case we ever move the patch to IPython and remove these APIs,
#    1761     # don't break on our side.
#    1762     return
#    1763 backend2gui_rif = {
#    1764     "qt": "qt",
#    1765     "gtk3": "gtk3",
#    (...)
#    1768     "macosx": "osx",
#    1769 }.get(cls.required_interactive_framework)
#
# File /home/tools/anaconda3/lib/python3.10/site-packages/IPython/core/pylabtools.py:77, in __getattr__(name)
#      75 def __getattr__(name):
#      76     if name in ("backends", "backend2gui"):
# ---> 77         warnings.warn(
#      78             f"{name} is deprecated since IPython 8.24, backends are managed "
#      79             "in matplotlib and can be externally registered.",
#      80             DeprecationWarning,
#      81         )
#      82         return globals()[f"_deprecated_{name}"]
#      83     raise AttributeError(f"module {__name__!r} has no attribute {name!r}")
#
# DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
